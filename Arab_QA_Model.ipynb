# %% [markdown]
# ##**Dataset**(JSON.File)

# %% [markdown]
# **import**

# %%
import json

# %% [markdown]
# **Json File**

# %%
def import_qas_data(datapath):
    with open(datapath) as data_file:
        data = json.load(data_file)

    data_entity_list = []
    for item in data['data']:
        entity = DataEntity(item['title'], item['paragraphs'])
        data_entity_list.append(entity)
    return data_entity_list

# %%
class DataEntity:
    def __init__(self, title, paragraph_data):
        self._title_ = title
        self._paragraphs_ = []
        for item in paragraph_data:
            paragraph = Paragraph(item['context'], item['qas'])
            self._paragraphs_.append(paragraph)

# %%
class Paragraph:
    def __init__(self, context, qas):
        self._context_ = context
        self._qas_ = []
        for answer in qas:
            qa = QAEntity(answer['question'], answer['id'])
            for item in answer['answers']:
                a = Answer(item['answer_start'], item['text'])
                qa._answers_.append(a)
            self._qas_.append(qa)

# %%
class QAEntity:
    def __init__(self, question, id):
        self._question_ = question
        self._id_ = id
        self._answers_ = []

# %%
class Answer:
    def __init__(self, answer_start, text):
        self._answer_start_ = answer_start
        self._text_ = text

# %% [markdown]
# ##**Tokenize**

# %% [markdown]
# **import**

# %%
import nltk
nltk.download('punkt')
import numpy as np
from keras.preprocessing.sequence import pad_sequences
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %% [markdown]
# **Tokenize**

# %%
def tokenize(sent):
    '''Return the tokens of a sentence including punctuation.
    >>> tokenize('جمال أحمد حمزة خاشقجي ، صحفي و إعلامي سعودي.من هو جمال أحمد حمزة خاشقجي؟')
    [جمال', 'أحمد','حمزة','خاشقجي','،','صحفي','و','إعلامي','سعودي','.','من','هو','جمال','أحمد','حمزة','خاشقجي','؟''ك]
    '''
    return [token.replace("``", '"').replace("''", '"') for token in nltk.word_tokenize(sent)]

# %%
tokenize('جمال أحمد حمزة خاشقجي ، صحفي و إعلامي سعودي.من هو جمال أحمد حمزة خاشقجي؟')
# Out:
# ['جمال',
#  'أحمد',
#  'حمزة',
#  'خاشقجي',
#  '،',
#  'صحفي',
#  'و',
#  'إعلامي',
#  'سعودي.من',
#  'هو',
#  'جمال',
#  'أحمد',
#  'حمزة',
#  'خاشقجي؟']

# %%
def tokenizeVal(sent):
    '''Return the tokens of a sentence including punctuation.
    >>> tokenize('جمال أحمد حمزة خاشقجي ، صحفي و إعلامي سعودي.من هو جمال أحمد حمزة خاشقجي؟')
    [جمال', 'أحمد','حمزة','خاشقجي','،','صحفي','و','إعلامي','سعودي','.','من','هو','جمال','أحمد','حمزة','خاشقجي','؟''ك]
    '''
    tokenizedSent = [token.replace("``", '"').replace("''", '"') for token in nltk.word_tokenize(sent)]
    tokenIdx2CharIdx = [None] * len(tokenizedSent)
    idx = 0
    token_idx = 0
    while idx < len(sent) and token_idx < len(tokenizedSent):
        word = tokenizedSent[token_idx]
        if sent[idx:idx+len(word)] == word:
            tokenIdx2CharIdx[token_idx] = idx
            idx += len(word)
            token_idx += 1 
        else:
            idx += 1
    return tokenizedSent, tokenIdx2CharIdx

# %%
tokenizeVal('جمال أحمد حمزة خاشقجي ، صحفي و إعلامي سعودي.من هو جمال أحمد حمزة خاشقجي؟')
# Out:
# (['جمال',
#   'أحمد',
#   'حمزة',
#   'خاشقجي',
#   '،',
#   'صحفي',
#   'و',
#   'إعلامي',
#   'سعودي.من',
#   'هو',
#   'جمال',
#   'أحمد',
#   'حمزة',
#   'خاشقجي؟'],
#  [0, 5, 10, 15, 22, 24, 29, 31, 38, 47, 50, 55, 60, 65])

# %% [markdown]
# # **Datasets**

# %%
def splitDatasets(f):
    '''Given a parsed Json data object, split the object into training context (paragraph), question, answer matrices, 
       and keep track of max context and question lengths.
    '''
    xContext = [] # list of contexts paragraphs
    xQuestion = [] # list of questions
    xQuestion_id = [] # list of question id
    xAnswerBegin = [] # list of indices of the beginning word in each answer span
    xAnswerEnd = [] # list of indices of the ending word in each answer span
    xAnswerText = [] # list of the answer text
    maxLenContext = 0
    maxLenQuestion = 0

    for data in f:
        paragraphs = data._paragraphs_
        for paragraph in paragraphs:
            context = paragraph._context_
            context1 = context.replace("''", '" ')
            context1 = context1.replace("``", '" ')
            contextTokenized = tokenize(context.lower())
            contextLength = len(contextTokenized)
            if contextLength > maxLenContext:
                maxLenContext = contextLength
            qas = paragraph._qas_
            for qa in qas:
                question = qa._question_
                question = question.replace("''", '" ')
                question = question.replace("``", '" ')
                questionTokenized = tokenize(question.lower())
                if len(questionTokenized) > maxLenQuestion:
                    maxLenQuestion = len(questionTokenized)
                question_id = qa._id_
                answers = qa._answers_
                for answer in answers:
                    answerText = answer._text_
                    answerTokenized = tokenize(answerText.lower())
                    # find indices of beginning/ending words of answer span among tokenized context
                    contextToAnswerFirstWord = context1[:answer._answer_start_ + len(answerTokenized[0])]
                    answerBeginIndex = len(tokenize(contextToAnswerFirstWord.lower())) - 1
                    answerEndIndex = answerBeginIndex + len(answerTokenized) - 1
                    
                    xContext.append(contextTokenized)
                    xQuestion.append(questionTokenized)
                    xQuestion_id.append(str(question_id))
                    xAnswerBegin.append(answerBeginIndex)
                    xAnswerEnd.append(answerEndIndex)
                    xAnswerText.append(answerText)


    return xContext, xQuestion, xQuestion_id, xAnswerBegin, xAnswerEnd, xAnswerText, maxLenContext, maxLenQuestion

# %%
# for validation dataset, as there's no need to keep track of answers
def splitValDatasets(f):
    '''Given a parsed Json data object, split the object into training context (paragraph), question, answer matrices, 
       and keep track of max context and question lengths.
    '''
    xContext = [] # list of contexts paragraphs
    xQuestion = [] # list of questions
    xQuestion_id = [] # list of question id
    xToken2CharIdx = []
    xContextOriginal = []
    maxLenContext = 0
    maxLenQuestion = 0

    for data in f:
        paragraphs = data._paragraphs_
        for paragraph in paragraphs:
            context = paragraph._context_
            context1 = context.replace("''", '" ')
            context1 = context1.replace("``", '" ')
            contextTokenized, tokenIdx2CharIdx = tokenizeVal(context1.lower())
            contextLength = len(contextTokenized)
            if contextLength > maxLenContext:
                maxLenContext = contextLength
            qas = paragraph._qas_
            for qa in qas:
                question = qa._question_
                question = question.replace("''", '" ')
                question = question.replace("``", '" ')
                questionTokenized = tokenize(question.lower())
                if len(questionTokenized) > maxLenQuestion:
                    maxLenQuestion = len(questionTokenized)
                question_id = qa._id_
                answers = qa._answers_
                
                xToken2CharIdx.append(tokenIdx2CharIdx)
                xContextOriginal.append(context)
                xContext.append(contextTokenized)
                xQuestion.append(questionTokenized)
                xQuestion_id.append(str(question_id))

    return xContext, xToken2CharIdx, xContextOriginal, xQuestion, xQuestion_id, maxLenContext, maxLenQuestion

# %%
trainData =import_qas_data('arcd.json')
tContext, tQuestion, tQuestion_id, tAnswerBegin, tAnswerEnd, tAnswerText, maxLenTContext, maxLenTQuestion = splitDatasets(trainData)

# %%
tAnswerText
# Out:
# ['صحفي وإعلامي',
#  'حمزة خاشقجي (13 أكتوبر 1958، المدينة المنورة - 2 أكتوبر 2018)،',
#  'المدينة المنورة',
#  'واشنطن بوست',
#  'وُصف في الصحف وأجهزة الاعلام العالمية بأنه "وفيّ للدولة السعودية" و"منتقد لسياساتها".',
#  'وتقلّد منصب مستشار،',
#  'في سبتمبر 2017،',
#  'الحكومة السعودية.',
#  'ولي العهد السعودي محمد بن سلمان، والملك سلمان بن عبد العزيز.',
#  'المملكة العربية السعودية)',
#  'الجنوب الغربي',
#  'حوالي مليوني كيلومتر مربع.',
#  'يحدها من الشمال العراق والأردن',
#  'الكويت',
#  'قطر والإمارات العربية المتحدة بالإضافة إلى البحرين التي ترتبط بالسعودية من خلال جسر الملك',
#  'أول تلك الكيانات إمارة الدرعية',
#  'محمد بن سعود',
#  'سنة 1157 هـ / 1744',
#  'تقع في الركن الشمالي الشرقي من قارة أفريقيا،',
#  'حيث تقع شبه جزيرة سيناء داخل',
#  'قُدّر عدد سكانها بـ104 مليون نسمة،',
#  '1115 كم،',
#  'مع السودان',
#  'حوالي 1.002.000 كيلومتر مربع',
#  'مصر في وادي النيل وفي الحضر',
#  'أقل من 4% من المساحة الكلية للبلاد أي حوالي 33000 كم2،',
#  'هي القاهرة الكبرى',
#  'أَبُو القَاسِم مُحَمَّد بنِ عَبد الله بنِ عَبدِ المُطَّلِب',
#  'ليعيدهم إلى توحيد الله',
#  'أَبُو القَاسِم مُحَمَّد بنِ عَبد الله بنِ عَبدِ المُطَّلِب',
#  '«صلى الله عليه وسلم»',
#  'في نفوس المسلمين،',
#  '«الإنسان الوحيد في التاريخ الذي نجح نجاحًا مطلقًا على',
#  'في مكة.',
#  'أمه في سنّ مبكرة',
#  'في سنِّ الخامسة والعشرين',
#  'تقع في أقصى غرب شمال أفريقيا',
#  'الرباط',
#  'الدار البيضاء',
#  'منذ 1956',
#  'منذ 1958',
#  'منذ 1959',
#  'الانتخابات البرلمانية لعام 2011',
#  '45,44%',
#  'هو حزب العدالة والتنمية بعد حصوله',
#  'عثمان الأول بن أرطغرل،',
#  '27 يوليو 1299م',
#  'واستمرت قائمة لما يقرب من 600 سنة،',
#  'بعد سنة 1354م،',
#  'سنة 1453م،',
#  'Yüce Osmanlı Devleti)',
#  'أوروبا وآسيا وأفريقيا،',
#  'سنة 1517م،',
#  'سنة 1565م؛',
#  'خمسِين وِلاية',
#  'United States of America',
#  'جُمهُورِيّة دُستُورِيّة اِتِّحادِيّة(1)',
#  'الشّمال الغربِيّ من القارّة،',
#  'في مُنتصف المُحِيطُ الهادِئ.',
#  'كندا',
#  '(3.79 مَليون مِيل مُربّع أو 9.83 مَليون كم²)،',
#  'وتتميَّز الوِلايات المُتّحِدَة بِأَنّها وَاحِدَة من أَكثر دُوَلِ العالَم تنوُّعاً من حيث العِرق والثَّقافة،',
#  '14.3 تِرِيلِيُون دُولَار أَمرِيكِيّ',
#  '28 يوليو 1914',
#  '11 نوفمبر 1918.',
#  'أوروبا',
#  'أكثر من 70 مليون فرد عسكري،',
#  'في بداية الحرب العالمية الثانية بعد عشرين سنة.',
#  '1914',
#  '28 يونيو 1914،',
#  'وفي 23 يوليو،',
#  'بين عامي 1908 و 1914،',
#  'في الأول من سبتمبر من عام 1939',
#  'الثاني من سبتمبر عام 1945،',
#  'أكثر من 30 بلدًا،',
#  'ما بين 50 و85 مليون قتيل',
#  'هيروشيما وناغازاكي،',
#  'حوالي مليون شخص،',
#  '7 يوليو 1937،',
#  'ومن أواخر عام 1939 إلى أوائل عام 1941،',
#  'بولندا، وفنلندا، ورومانيا، ودول البلطيق.',
#  'روسيا',
#  '14 يونيو ولغاية 15 يوليو من عام 2018.',
#  '2 ديسمبر 2010.',
#  'ألمانيا.',
#  'بطولة كأس العالم 2006',
#  '3 ترشيحات',
#  'الجانب الغربي من روسيا،',
#  '11 مدينة روسية.',
#  'العاصمة موسكو',
#  '262',
#  '1193',
#  'الدولة الأيوبية',
#  'معركة حطين.',
#  'الفرنجة وغيرهم من الصليبيين الأوروبيين',
#  'معظم أراضي فلسطين ولبنان بما فيها مدينة القدس،',
#  'بمذهب أهل السنة والجماعة،',
#  'بتسامحه ومعاملته الإنسانية لأعدائه،',
#  'عن بسالته في عدد من المواقف، أبرزها عند حصاره لقلعة الكرك في مؤاب،',
#  'بغداد،',
#  'الخليج العربي.',
#  'ثمان عشرة محافظة',
#  'الكويت والمملكة العربية السعودية،',
#  'تركيا',
#  'سوريا والأردن،',
#  'بحوالي 37,547,686 نسمة،',
#  'من 75% إلى 80%',
#  '15%',
#  '1879',
#  '1955)',
#  '1921',
#  'تفسير العديد من الظواهر العلمية التي فشلت الفيزياء الكلاسيكية في إثباتها.',
#  '1915',
#  'الجاذبية،',
#  'المدرسة التقنية الفدرالية السويسرية في زيورخ',
#  '1900.',
#  'زيورخ',
#  '309.500 كم².',
#  'غرب آسيا',
#  'في الربع الجنوبي الشرقي',
#  'النفوذ في منطقة الخليج العربي والمحيط الهندي',
#  'الميناء التجاري الرئيسي',
#  'من بين أهم الموانئ التجارية',
#  'باسم جبل النحاس',
#  'أربعة مواقع',
#  'لتاريخ البلاد وثقافتها وتنوع تضاريسها الجغرافية.',
#  'دمشق،',
#  'تركيا،',
#  'العراق،',
#  'الأردن،',
#  'فلسطين، ولبنان،',
#  '14 محافظة،',
#  'أقدم مدينة في العالم،',
#  '1920',
#  '1936',
#  'تقع في جنوب آسيا.',
#  'تعدّ سابع أكبر بلد من حيث المساحة الجغرافية،',
#  'والثانية من حيث عدد السكان،',
#  'كانت شبه القارة الهندية معروفة بثراوتها التجارية والثقافية لفترة كبيرة من تاريخها الطويل.',
#  'استقلت الهند في عام 1947',
#  'استعمرت من قبل المملكة المتحدة',
#  'تتألف من 28 ولاية',
#  'وسبعة أقاليم',
#  'تحتل الهند المرتبة السادسة في الإنفاق العسكري بين الدول.',
#  'في غرب آسيا',
#  'تشمل إسرائيل، والضفة الغربية، وقطاع غزة، وفي بعض التعاريف، بعض أجزاء من غرب الأردن',
#  '(بالعبرية: פלשתינה أو פלסטין',
#  'باليونانية: Παλαιστίνη)',
#  'عام 2005',
#  '11,900,000 نسمة تقريباً',
#  'سورية والأردن،',
#  'لبنان،',
#  'مستطيلة الشكل',
#  'Cancer)',
#  'هو مجموعة من الأمراض التي تتميز خلاياها بالعدائية Aggressive',
#  'الخلايا المنقسمة لها القدرة على غزو Invasion الأنسجة المجاورة وتدميرها، أو الانتقال إلى أنسجة',
#  'إلى سرطان خبيث في بعض الأحيان.',
#  'القدرة على غزو Invasion الأنسجة المجاورة وتدميرها، أو الانتقال إلى أنسجة بعيدة',
#  'مجموعة من الأمراض التي تتميز خلاياها بالعدائية Aggressive (وهو النمو والانقسام الخلوي غير المحدود)،',
#  'يستطيع السرطان أن يصيب كل المراحل العمرية عند الإنسان حتى الأجنة،',
#  'تزيد مخاطر الإصابة به كلما تقدم الإنسان في العمر.',
#  '7.6 مليون شخص',
#  '(8 أكتوبر 1980',
#  'مصرية.',
#  'مغنية',
#  'أوائل عام 2002',
#  'زغرطي يا انشراح',
#  'شيرين',
#  '7 أبريل 2018',
#  'من المطرب المصري حسام حبيب',
#  'مجلة الجرس',
#  '中国',
#  '中华人民共和国',
#  '1.338 مليار نسمة.',
#  'شرق آسيا',
#  '22 مقاطعة',
#  'وخمس مناطق ذاتية الحكم',
#  'ثالث أو رابع أكبر من المساحة الإجمالية',
#  'وثاني أكبرها وفقًا لمساحة البر.',
#  '14,500 كيلومتر',
#  'رياضة جماعية تُلعب بين فريقين يتكون كل منهما من أحد عشر لاعباً',
#  'بكرة مُكوَّرة.',
#  'الرياضة الأكثر شعبية وانتشاراً في العالم.',
#  'كرة القدم هي رياضة جماعية',
#  'ملعب مستطيل الشكل مع مرميين في جانبيه.',
#  'الهدف من اللعبة هو إحراز الأهداف بركل الكرة داخل المرمى.',
#  'حارس المرمى هو اللاعب الوحيد الذي يُسمح له أن يلمس الكرة بيديه أو ذراعيه،',
#  'يستخدم اللاعبون غير الحارس أرجلهم غالباً في الهجوم أو تمرير الكرة ويمكنهم أيضاً استخدام',
#  'الفريق الذي يحرز أهدافاً أكثر يكون هو الفائز.',
#  'حرب أكتوبر "حرب العاشر من رمضان" كما تعرف في مصر',
#  'حرب تشرين التحريرية كما تعرف في سوريا',
#  'يوم كيبور) كما تعرف في إسرائيل،',
#  'هي حرب شنتها كل من مصر وسوريا على إسرائيل',
#  'عام 1973',
#  'جانب الضفة الغربية من الأردن بالإضافة إلى قطاع غزة الخاضع آنذاك لحكم عسكري مصري.',
#  'عقب بدء الهجوم حققت القوات المسلحة المصرية والسورية أهدافها من شن الحرب على إسرائيل،',
#  'القوات السورية من الدخول إلى عمق هضبة الجولان وصولاً إلى سهل الحولة وبحيرة طبريا.',
#  'فعبرت القوات المصرية قناة السويس بنجاح وحطمت حصون خط بارليف وتوغلت 20 كم شرقاً',
#  'نجيب محفوظ (11 ديسمبر',
#  '(11 ديسمبر 1911',
#  '30 أغسطس 2006)',
#  'هو أول عربي حائز على جائزة نوبل في الأدب',
#  '.كتب نجيب محفوظ منذ بداية الأربعينيات',
#  'تدور أحداث جميع رواياته في مصر،',
#  'وُلد نجيب محفوظ عبد العزيز إبراهيم أحمد الباشا في حي الجمالية بالقاهرة.',
#  'يقرأ كتاباً في حياته بعد القرآن غير "حديث عيسى بن هشام" لأن كاتبه المويلحي',
#  'كان عمره 7 أعوامٍ حين قامت ثورة 1919',
#  'غزوة بدر (وتُسمى أيضاً غزوة بدر الكبرى وبدر القتال ويوم الفرقان)',
#  'هي غزوة وقعت في السابع عشر من رمضان في العام الثاني من الهجرة',
#  'بين المسلمين بقيادة رسول الإسلام محمد، وقبيلة قريش ومن حالفها من العرب بقيادة عمرو',
#  'المسلمين بقيادة رسول الإسلام محمد،',
#  'وقبيلة قريش ومن حالفها من العرب بقيادة عمرو بن هشام المخزومي القرشي.',
#  'وقد سُميت بهذا الاسم نسبةً إلى منطقة بدر التي وقعت المعركة فيها،',
#  'جمادى الأولى وجمادى الآخرة سنة 2 هـ في مئة وخمسين أو مئتين من المهاجرين',
#  'لاعتراض عير لقريش ذاهبة من مكة إلى الشام،',
#  'فلما وصل مكاناً يُسمى "ذا العشيرة" وجد العير قد فاتته بأيام.',
#  'أوروبا إحدى قارات العالم السبع.',
#  'وجغرافيًا تعد شبه جزيرة كبيرة',
#  'والبحر الأبيض المتوسط والبحر الأسود ومنطقة القوقاز من الجنوب والمحيط المتجمد الشمالي من الشمال.',
#  'وتعتبر قارة صغيرة نسبيا مقارنة ببقية القارات',
#  'لكن قارة أستراليا أصغر منها.',
#  'الجغرافية يعود مفهوم حدود القارة إلى العصور القديمة الكلاسيكية، حيث أصبح مصطلح "القارة" جغرافيّا',
#  'وكلمة أوربَّا أصلها إغريقي',
#  'وتعني الوجه العريض،',
#  'وتصل مساحة القارة لحوالي 10.180 مليون (7.1 % من مساحة الأرض).',
#  'بلد في شرق آسيا، تقع بين المحيط الهادئ وبحر اليابان، وشرق شبه الجزيرة الكورية.',
#  'الشمس',
#  'المنبع أو الأصل.)',
#  'لوقوعها في أقصى شرقي العالم المأهول آنذاك.',
#  '(حوالي ثلاثة آلاف جزيرة)،',
#  'في عام 1947',
#  '47 محافظة.',
#  'ثماني مناطق',
#  '128 مليون نسمة.',
#  '(20 أغسطس 1858',
#  '16 سبتمبر 1931)،',
#  'بشيخ الشهداء، وشيخ المجاهدين، وأسد الصحراء،',
#  'عُمر المنفي الهلالي',
#  'قائد أدوار السنوسية في ليبيا،',
#  'قبيلة منفة الهلالية التي تنتقل في بادية برقة.',
#  '53 عامًا',
#  'لأكثر من عشرين عامًا',
#  'بإعدامه شنقًا،',
#  'في الشرق الأوسط في غرب القارة الآسيوية.',
#  'سوريا',
#  'وفلسطين المحتلة - إسرائيل',
#  'تعدد الحضارات',
#  'لموقعه الوسطي بين الشمال الأوروبي والجنوب العربي والشرق الآسيوي والغرب الأفريقي،',
#  '7000 سنة.',
#  'الفينيقيون',
#  'الملاحة والتجارة',
#  'المصريين القدماء، الآشوريين، الفرس، الإغريق، الرومان، الروم البيزنطيين، العرب، الصليبيين، الأتراك العثمانيين، فالفرنسيين.',
#  'الاسم الأخير',
#  'لتمييزها عن دول السَّلاجقة اللاَّحقة التي ظهرت بعد تفكِّكها وانهيارها)',
#  'الدولة العباسية والحروب الصليبية والصِّراع الإسلامي البيزنطي.',
#  'على يد سلالة السَّلاجقة،',
#  'وهي سلالة تركيَّة تنحدر من قبيلة قنق التي تنتمي بدورها إلى مجموعة أتراك الأوغوز.',
#  'إيران وأفغانستان ووسط آسيا وُصولاً إلى كاشغر في الشرق، فضلاً عن العراق والشام والأناضول',
#  'قبيلة "قنق" إحدى العشائر المتزعمة لقبائل الغز التركية.',
#  'سنة 960م.',
#  'في عام 1037م (429 هـ).',
#  'التقويم الميلادي هو التقويم المستعمل مدنيًّا في أكثر دول العالم.يسمى',
#  'لأن عدَّ السنين فيه يبدأ من سنة ميلاد المسيح',
#  'وهو الراهب الأرمني دنيسيوس الصغير.',
#  'بالتقويم الغريغوري',
#  'نسبة إلى البابا غريغوريوس الثالث عشر بابا روما',
#  'بمعنى أنها تمثل دورة كاملة للشمس في منازلها،',
#  'عشرة أشهر،',
#  'السنة فيه 354 يومًا',
#  'سنة 753 ق.م.',
#  'رئيس جمهورية تركيا الثاني عشر',
#  'اختاره الشعب بطريق الاقتراع المباشر،',
#  'في 9 يوليو 2018',
#  'من مارس 2003 حتى أغسطس 2014',
#  'عمدة مدينة إسطنبول',
#  'حزب العدالة والتنمية',
#  'كرة قدم',
#  'نادي قاسم باشا',
#  'بالتحريض على الكراهية الدينية',
#  'مذهب إسلامي.',
#  'منهج أو طريق يسلكه العبد للوصول إلى الله،',
#  'عن طريق الاجتهاد في العبادات واجتناب المنهيات،',
#  'يستمد أصوله وفروعه من القرآن والسنة النبوية',
#  'لابن عطاء الله السكندري،',
#  'للإمام القشيري،',
#  'الشيخ ابن الجوزي',
#  'إلى (صوفة بن مرة)',
#  'كل من ينقطع عن الدنيا وينصرف إلى العبادة فقط.',
#  'الاِتِّحَاد السُّوَيْسْرِيّ',
#  '26 كانتون،',
#  'برن',
#  'غرب أوروبا،',
#  'ألمانيا',
#  'بتنوّعها الديني واللغوي وتمسكها بممارسة الديمقراطية المباشرة.',
#  'عضو مؤسس في الرابطة الأوروبية للتجارة الحرة؛',
#  'المدينتين الثانية والثامنة',
#  'الدولة التاسعة عشر',
#  'في غرب آسيا.',
#  '81 مليون نسمة',
#  'السعودية',
#  'أرمينيا وأذربيجان وتركمانستان.',
#  'طهران',
#  'النفط والغاز الطبيعي.',
#  'في 2800 قبل الميلاد.',
#  'الميديون',
#  'والدولة الصفارية والسامانيون والبويهيون.',
#  '6 نوفمبر 1494 بطرابزون،',
#  'الثمانون،',
#  '"أمير المؤمنين" من آل عثمان.',
#  'أقصى اتساع لها',
#  'أقوى دولة في العالم في ذلك الوقت.',
#  'من 6 نوفمبر 1520م حتى وفاته في 7 سبتمبر سنة 1566م',
#  'سليمان العظيم',
#  'في القرن السادس عشر،',
#  'في 1529م.',
#  'في عام 2002',
#  '-)',
#  'جائزة أفضل فنان أفريقي من الأفريكان ميوزك أوورد عام 2010.',
#  'بكلية الإعلام في جامعة 6 أكتوبر،',
#  'وبدأ مشواره الفني خلال دراسته الجامعية فقد كان يغني بحفلات الجامعة.',
#  'كانت أغنية "شكلي هاحبك" أول أغنية تسجل له على شريط',
#  'في بداية 2006',
#  'قضي تامر 6 أشهر في السجن العسكري بعد تخفيف العقوبة.',
#  'تزوير شهادة أداء الخدمة العسكرية وما حدث أنني استعنت ببعض المعارف لإسألهم عنها ولأعرف',
#  'هو عبد الرحمن بن محمد، ابن خلدون أبو زيد، ولي الدين الحضرمي الإشبيلي',
#  '(1332',
#  'في تونس',
#  'جامعة الزيتونة،',
#  'وديوان المبتدأ والخبر في معرفة أيام العرب والعجم والبربر ومن عاصرهم من ذوي السلطان',
#  'وليَ الكتابة والوساطة بين الملوك في بلاد المغرب والأندلس ثم انتقل إلى مصر',
#  'تُوُفِّيَ عام 1406',
#  'ويعتبر ابنُ خَلدون مؤسسَ علم الاجتماع الحديث ومن علماء التاريخ والاقتصاد.',
#  'ستة وسبعين عامًا ودُفِنَ قرب باب النصر بشمال القاهرة',
#  'منتج أفلام كندي من أصل سويسري يدعى برنارد فيبر',
#  'عام 1999،',
#  'العالم المفتوح الجديد (New Open World Corporation).',
#  'عالم الرياضيات فيلو البيزنطي',
#  'أفضل النسخ الموجودة كانت لشاعر يوناني يدعى أنتيباتر الصيداوي،',
#  'المخطوطة الوحيدة التي بقيت من هذا الكتاب ذكرت ستة عجائب فقط،',
#  'انتهى بناؤه في العام 280 قبل الميلاد،',
#  'الزلزال الذي حصل في العام 225/226 قبل الميلاد،',
#  'لمدة لا تزيد عن 60 سنة.',
#  'السُّكَّري أو الداء السكري أو المرض السكري أو مرض السكر أو البوال السكري',
#  'Diabetes mellitus)',
#  'الدم الناجم عن عوز هرمون الأنسولين، أو انخفاض حساسية الأنسجة للأنسولين، أو كلا الأمرين.',
#  'يؤدي السكري إلى مضاعفات خطيرة أو حتى الوفاة المبكرة؛',
#  'خفض الوزن، وكثرة الحركة.',
#  'عوز هرمون الأنسولين، أو انخفاض حساسية الأنسجة للأنسولين، أو كلا الأمرين.',
#  'دراسة أُجريت في الولايات المتحدة في عام 2008 أن العديد من النساء الأمريكيات تعانين',
#  'من خطر المضاعفات أثناء الحمل، كما يزداد خطر تطور السكري عند المولود في المستقبل.',
#  'معدل الإصابة بسكري الحوامل ازداد إلى أكثر من الضعف في السنوات الستة الأخيرة،',
#  'محمد علي باشا المسعود بن إبراهيم آغا القوللي',
#  'هو مؤسس الأسرة العلوية وحاكم مصر ما بين عامي 1805 إلى 1848،',
#  'Kavalalı Mehmet Ali Paşa؛',
#  'عام 1805',
#  'بايعه أعيان البلاد ليكون واليًا عليها، بعد أن ثار الشعب على سلفه خورشيد باشا،',
#  'ما بين عامي 1805 إلى 1848،',
#  'استطاع أن ينهض بمصر عسكريًا وتعليميًا وصناعيًا وزراعيًا وتجاريًا، مما جعل من مصر دولة',
#  '18 يونيو سنة 1953 م،',
#  'بسبب ضعف خلفائه وتفريطهم في ما حققه من مكاسب',
#  'العُثمانيَّة هُم مجموعةُ من السلاطين التُرك المُسلمين السُنَّة من آل عُثمان حكموا إمبراطوريَّة مُترامية',
#  'ودام مُلكُهم من عام 1299م إلى عام 1922م.',
#  'امتدَّت أراضيها على ثلاث قارَّات،',
#  'من المجر شمالًا',
#  'الحبشة جنوبًا (ما يُعرف بالصومال حاليًّا)،',
#  'أذربيجان شرقًا (بعض أنحاء مُحافظة أذربيجان الشرقيَّة في إيران حاليًّا).',
#  'وفي عام 1366م',
#  'السُلطان مُحمَّد الثاني',
#  'عام 1453م،',
#  'عائلة يهودية ألمانية ثرية جداً،',
#  'تأسست على يد إسحق إكانان وبزغت',
#  'يعني "الدرع الأحمر"،',
#  'في خمس دول أوروبية،',
#  '(أتسليم)',
#  'أما (كارل)',
#  'أقرضت هذه العائلة 100 مليون جنيه',
#  'بمبلغ 16 مليون جنيه',
#  'الحرب العالمية الثانية).',
#  'هو مسلسل فنتازيا ملحمي',
#  'تأليف ديفيد بينيوف ودانيال وايز',
#  'قناةِ اتش بي او',
#  'يعمل كمنتجٍ تنفيذيّ للمسلسل ويَكتُبْ حلقةً واحدةً في كل موسم،',
#  'في 17 أبريل 2011.',
#  '7 مواسِم',
#  'في قارّتين خياليتين هما ويستروس وإيسوس',
#  'راية آل تاغاريان.',
#  'القارة إيسوس،',
#  'المصاب أنّ فكرة معيّنة تلازمه دائماً وتحتلّ جزءًا من الوعي والشعور لديه وذلك بشكلٍ',
#  'تسيطر فكرة ما على الذهن بشكل لا يمكن التفكير بغيرها.',
#  'الحاجة إلى تفقّد الأشياء بشكل مستمر، أو ممارسة عادات وطقوس بشكل متكرّر،',
#  'ويشعر بالقلق والتوتر',
#  'مقياس ييل-براون الوسواسي القهري (Y-BOCS)',
#  'اضطراب القلق والاضطراب الاكتئابي واضطراب الأكل واضطراب الشخصية الوسواسية.',
#  '2.3%',
#  'قبل سنّ العشرين؛',
#  'تتساوى نسبة الإصابة به بين الرجال والنساء.',
#  'أبو عبد الله محمد بن إدريس الشافعيّ المطَّلِبيّ القرشيّ',
#  'هو ثالث الأئمة',
#  'ومؤسس علم أصول الفقه، وهو أيضاً إمام في علم التفسير وعلم الحديث،',
#  'قال فيه الإمام أحمد: «كان الشافعي كالشمس للدنيا، وكالعافية للناس»،',
#  'كان الشافعي فصيحاً شاعراً، ورامياً ماهراً، ورحّالاً مسافراً.',
#  'عمل قاضياً',
#  'عام 150 هـ،',
#  'كتاب الرسالة',
#  'سنة 204 هـ.',
#  'مخترع ورجل أعمال أمريكي.',
#  'ألفا',
#  'العالم، مثل تطوير جهاز الفونوغراف وآلة التصوير السينمائي بالإضافة إلى المصباح الكهربائي المتوهج العملي',
#  '"ساحر مينلو بارك" (The Wizard of Menlo Park)',
#  'أول من أنشأ مختبرًا للأبحاث الصناعية.',
#  'قاموا بتطبيق مبدأ الإنتاج الشامل والعمل الجماعي على نطاق واسع لعملية الإختراع،',
#  '1093',
#  'في وسائل الاتصال الجماهيري وفي مجال الاتصالات',
#  'والبطارية الكهربائية للسيارة',
#  'رسول الله والمسيح في الإسلام،',
#  'ليقود بني إسرائيل إلى كتاب مقدس جديد',
#  'الإنجيل،',
#  'توقيراً لهم.',
#  'الإيمان بعيسى (وكل الأنبياء والرسل)',
#  '25 مرة،',
#  'النبي زكريا،',
#  'أباً للنبي يحيى.',
#  'لتلد عيسى وهي عذراء.',
#  'الإتحاد السوفيتي',
#  '(سايوز سافيتسكيخ سوتسياليستيتسشكخ ريسبوبليك)',
#  'شملت حدودها أغلب مساحة منطقة أوراسيا',
#  '"النصيحة"',
#  'المرجعية الأساسية للمجتمع والنظام الشيوعي في اتحاد الجمهوريات السوفيتية الاشتراكية.',
#  'ككيان',
#  'من رحم الإمبراطورية الروسية',
#  'أربعة أعوام',
#  'الاتحاد السوفيتي',
#  'هو نادٍ رياضيّ، ثقافيّ، اجتماعيّ',
#  '1957،',
#  'الفريق الأول في السعودية من حيث عدد البطولات المحلية،',
#  'قائمة أفضل 100 فريق كرة قدم في العالم',
#  'الرياض',
#  'المرتبة التاسعة والسبعين عالميا',
#  '(بكأس الأمير فيصل بن فهد)',
#  'حصول نادي الهلال السعودي على لقب نادي القرن في قارة آسيا',
#  'ثمان مرات',
#  'تتركز أساسًا في الوطن العربي',
#  'كازاخستان',
#  'فرع من فروع الشعوب السامية',
#  'في الأمريكيتين وفي أوروبا وإيران وتركيا.',
#  'على خلفيات إما إثنية أو لغوية أو ثقافية.',
#  'هو كل شخص لغته الأم العربية ووالده عربي.',
#  'أن العرب اسم علم للشعب في البدو والحضر لا مضارب القبائل فحسب،',
#  'لحيان في القرن الرابع قبل الميلاد وايضا مملكة كندة في القرن الثاني قبل الميلاد؛',
#  'تعني غير أهل البادية،',
#  'الجرب،',
#  'وهو مرض جلدي معدي تسببه القارمة الجربية.',
#  'أكثر الاعراض شيوعا هي الحكة الشديدة وطفح جلدي يشبه البثور، وفي بعض الاحيان يمكن',
#  'العدوى الأولية تحتاج عادة من 2-6 أسابيع قبل ظهور الأعراض،',
#  'ويمكن لهذه الأعراض أن تظهر في معظم أنحاء الجسم أو في مناطق معينة فقط،',
#  'عادة ما يصيب الأطفال الصغار وليس البالغين.',
#  'يكون العث عادة صغير جدًا وغير ملاحظ بالعين المجردة،',
#  'من الأدوية لعلاج الأشخاص المصابين، بما في ذلك: بيرميثرين، كروتاميتون وكريمات يندين وحبوب الإيفرميكتين.',
#  'تختلف قليلا عن الحشرة التي تصيب الإنسان ولكنها ذات صلة بها وتعرف بجرب قارمي.',
#  'جبران خليل جبران شاعر وكاتب ورسام عربي لبناني من أدباء وشعراء المهجر،',
#  'ولد في 6 يناير 1883',
#  'الولايات المتحدة الأمريكية،',
#  'توفي في نيويورك 10 ابريل 1931',
#  'بداء السل.',
#  'اشتهر عند العالم الغربي بكتابه الذي تم نشره سنة 1923 وهو كتاب النبي',
#  'أسرته فقيرة بسبب كسل والده وانصرافه إلى السكر والقمار،',
#  'الطبيب الشاعر سليم الضاهر مما فتح أمامه مجال المطالعة والتعرف إلى التاريخ والعلوم والآداب.',
#  'في 25 يونيو 1895،',
#  '«إسپانيا الإسلاميَّة» أو «أيبيريا الإسلاميَّة»،',
#  'أوروپَّا الغربيَّة وتحديدًا في شبه الجزيرة الأيبيريَّة، على الأراضي التي تُشكِّلُ اليوم إسپانيا والپرتغال،',
#  'خلال القرن الثامن الميلاديّ',
#  'فتتقلَّص ثُمَّ تتوسَّع، ثُمَّ تعود فتتقلَّص، وهكذا، استنادًا إلى نتائج الحرب بين المُسلمين والإفرنج.',
#  'سنة 1492م',
#  'سقطت الأندلس بيد اللاتين الإفرنج',
#  'بادئ الأمر تُشكِّلُ ولايةً من ولايات الدولة الأُمويَّة زمن الخليفة الوليد بن عبد الملك،',
#  'المُثلثات، وإبراهيم بن يحيى الزرقالي في علم الفلك، وأبو القاسم الزهراوي في الجراحة، وابن',
#  'المُسلمون أهل الكتاب من اليهود والنصارى يرجعون إلى شرائعهم الخاصَّة للتقاضي والتظلُّم، لقاء الجزية.',
#  'يصيب الجهاز المناعي البشري ويسببه فيروس نقص المناعة البشرية فيروس إتش أي في (HIV)',
#  'التقليل من فاعلية الجهاز المناعي للإنسان بشكل تدريجي',
#  'AIDS؛',
#  'طريق حدوث اتصال مباشر بين غشاء مخاطي أو مجرى الدم وبين سائل جسدي يحتوي',
#  'أن ينتقل هذا الفيروس من خلال الاتصال الجنسي غير الآمن سواء الشرجي أو المهبلي',
#  'يمكن أن ينتقل من الأم إلى جنينها خلال مرحلة الحمل أو الولادة أو الرضاعة',
#  'عام 2007، تم تقدير عدد المصابين الأحياء بهذا المرض حول العالم بنحو 33.2 مليون',
#  'هذا المرض قد أودى بحياة ما يُقدر بحوالي 2.1 مليون شخص',
#  'القارة الأفريقية',
#  'الكعبة المشرفة',
#  'قبلة المسلمين في صلواتهم، وحولها يطوفون أثناء أداء فريضة الحج، كما أنها أول بيت',
#  'فريضة الحج،',
#  'يعتقد المسلمون أن من بنى الكعبة أول مرة هم الملائكة قبل آدم،',
#  'البيت الحرام،',
#  'لأن الله حرم القتال بها،',
#  'المسلمون أيضاً أن الله تعالى أمر النبي إبراهيم برفع قواعد الكعبة، وساعده ابنه إسماعيل',
#  'ولما اكتمل بناؤهما أمر الله إبراهيم أن يؤذّن في الناس بأن يزوروها ويحجوا إليها،',
#  '(سورة البقرة، الآية 127).',
#  'أعداد تقريبية لأعداد السكان في العالم',
#  'لعدد الذين عاشوا على الأرض في فترة زمنية سابقة،',
#  'الإجتماعي للسكان وتوزيعهم الجغرافي والحركة النشطة التي تتسم بها تغيرات السكان في البلاد المختلفة.',
#  '970000 مليون نسمة سنويا',
#  '6.9 مليار نسمة،',
#  'عام 2012.',
#  '1350،',
#  'وانخفض إلى 1.1%',
#  '1960',
#  '"ملكي اتحادي"',
#  'أوروبا',
#  'وهي عضو مؤسس في الاتحاد الأوروبي،',
#  '11،787 ميل مربع)،',
#  'حوالي 11 مليون',
#  'الاتحاد الأوروبي،',
#  'الهولندية',
#  'بروكسل،',
#  'جنوب والونيا.',
#  'إحدى دُولِ الخِلافةُ الإسلاميَّة،',
#  'الدَّوْلَةُ العُبَيْدِيَّةُ',
#  'والوحيدةُ بين دُولِ الخِلافةِ التي اتخذت من المذهب الشيعي',
#  'حول تحديد نسب الفاطميين،',
#  '358هـ',
#  'مصر',
#  'الجامع الأزهر ودار الحكمة',
#  'صلاح الدين الأيوبي',
#  '1171م',
#  'هو التهاب يصيب منطقة من المصران الأعور',
#  'عن انسداد رأس منطقة الزائدة الدودية ببقايا براز أو أي أجسام غريبة،',
#  'حالة إسعافية',
#  'أنواع من البكتيريا المفيدة',
#  'ليس لها فوائد للجسم البشري،',
#  'بمكانها',
#  'انسداد مدخل الزائدة الدودية ببقايا الغذاء الموجود في الأمعاء،',
#  'الديدان الطفيلية أو الأجسام الغريبة هي سبب انسداد مدخل الزائدة الدودية،',
#  'عندما يتفاقم الانسداد بتكاثر بكتيري تصبح الزائدة منتفخة وملتهبة ومليئة بالقيح',
#  'أحد شهداء الثورة الجزائرية،',
#  'في مدينة عين مليلة الواقعة في شرق الجزائر،',
#  'المدرسة الابتدائية الفرنسية بمسقط',
#  'ولما حصل على الشهادة الابتدائية',
#  '"فوج الرجاء"',
#  'مناضلا وقائدا',
#  'جعله عطوفا حنونا،',
#  'نشر الفكرة الوطنية والجهاد ضد الاستعمار.',
#  '"شاب مؤمن، بر وتقي، مخلص لدينه ولوطنه، بعيد كل البعد عن كل ما يشينه.',
#  'Communism',
#  'مجموعة أفكار في التنظيم السياسي والمجتمعي مبنية على الملكية المشتركة لوسائل الإنتاج في الاقتصاد؛',
#  'لإنهاء الطبقية الاجتماعية ولتغيّر مجتمعي يؤدي لانتفاء الحاجة للمال ومنظومة الدولة.',
#  'من اللاتنية: "communis", "common, universal")',
#  'هي أيدلوجيية اجتماعية اقتصادية سياسية وحركة هدفها الأساسي تأسيس مجتمع شيوعي بنظام اجتماعي اقتصادي',
#  'على الملكية المشتركة لوسائل الإنتاج في ظل غياب الطبقات المجتمعية والمال ومنظومة الدولة.',
#  'إلى السيطرة على المجتمع ومقدّراته لصالح أفراد المجتمع بالتساوي',
#  'كارل ماركس،',
#  'ويذكر أيضًا روزا لكسمبورغ',
#  'الاضطراب الوجداني ثنائي القطب أو أيضا الاضطراب ثنائي القطب، المعروف سابقا باسم الاكتئاب الهوسي،',
#  'اضطراب نفسي يسبب فترات من الاكتئاب وفترات من ارتفاع المزاج (الابتهاج) بشكل غير طبيعي،',
#  'فترات الهوس أو الهوس خفيف، اعتمادا على شدتها',
#  'كونها تؤدي بالشخص في بعض الأحيان للقيام بأعمال طائشة وغير مسؤولة أو مدروسة العواقب.',
#  'تتأثر الحاجة إلى النوم لدى الأشخاص المصابين وتقل.',
#  'الأشخاص المصابين أعراض من قبيل نوبات البكاء، ومشاهدون الحياة من وجهة نظر سلبية، بالإضافة',
#  'العوامل البيئية والوراثية',
#  'العوامل الوراثية',
#  'حوالي 85 في المائة',
#  'Mona Lisa،',
#  'ليوناردو دا فينشي،',
#  'خلال عصر النهضة الإيطالية.',
#  'الجيوكاندا',
#  '"أكثر الأعمال الفنية شهرة في تاريخِ الفن،',
#  'لوحةٌ فنيةٌ نصفيةٌ تعود للقرن السادس عشر لسيدةٍ يُعتقدُ بِأنها ليزا جوكوندو،',
#  'جورجيو فاساري',
#  '"جوكوندو".',
#  '"سعيد" أو "مرح".',
#  'اليوم الذي قتل فيه الحسين بن علي',
#  'اليوم العاشر من شهر مُحَرَّم في التقويم الهجري،',
#  'وهو اليوم الذي نجّىٰ الله فيه موسى من فرعون',
#  'بيوم عاشوراء',
#  'في معركة كربلاء،',
#  'إيران، باكستان، لبنان، البحرين، الهند والعراق والجزائر.',
#  'العاشر من محرم سنة 61 للهجرة،',
#  'جيش يزيد ابن معاوية.',
#  'زيارة ضريح الحسين وإضاءة الشموع وقراءة قصة الإمام الحسين والبكاء عند سماعها واللطم تعبيراً',
#  'Bitcoin)',
#  'هي عملة معماة ونظام دفع عالمي',
#  'العملة هي عملة إلكترونية بشكل كامل تتداول عبر الإنترنت فقط من دون وجود فيزيائي',
#  'وهي أول عملة رقمية لامركزية',
#  'شخص غير معروف أو مجموعة من الناس عرف باسم ساتوشي ناكاموتو',
#  'وأُصدِر كبرنامج مفتوح المصدر في عام 2009."\'',
#  'كمكافأة لعملية تعرف باسم التعدين.',
#  '100,000 تاجر وبائع',
#  'مابين 2.9 إلى 5.8 مليون مستخدم',
#  'هو مرض معد شائع وقاتل في كثير من الحالات',
#  'تُسببه سُلالات مُختلفة من البكتيريا الفُطْرية،',
#  'يُهاجم السل عادة الرئة،',
#  'عن طريق الهواء',
#  'واحدة من بين كل عشر حالات',
#  'حالة عدوى نشطة',
#  'السعال المزمن مع البلغم المشوب بالدم والحمى والتعرق الليلي وفقدان الوزن',
#  '"ضموري"',
#  'يعتمد التشخيص الطبي للإصابة بالسل النشط على الأشعة',
#  '11 سبتمبر 1965)',
#  'رئيس الجمهورية العربية السورية',
#  'حافظ الأسد',
#  '2000',
#  'تعديل استثنائي لدستور الجمهورية العربية السورية متعلق بعمر رئيس البلاد',
#  'باسل الأسد',
#  '15 آذار عام 2011',
#  'أواخر عام 2010،',
#  'الآلاف من الضحايا والجرحى والمعتقلين،',
#  'Nederland',
#  'اثنتي عشر مقاطعة،',
#  'ثلاث جزر',
#  'بحر الشمال من ناحيتي الشمال والغرب، وبلجيكا من الجنوب، وألمانيا من الشرق،',
#  'ديمقراطي برلماني،',
#  'أمستردام،',
#  '21%',
#  'أواخر القرن السادس عشر الميلادي',
#  'ثلاثة أنهار أوروبية',
#  'حيوان من الثدييات من فصيلة السنوريات وأحد السنوريات الأربعة الكبيرة المنتمية لجنس النمر',
#  'فصيلة السنوريات',
#  'Panthera)،',
#  'الأسد',
#  'الببر،',
#  'تفوق كتلة الذكور الكبيرة منه 250 كيلوغراما',
#  'بين 12 و14 عاما،',
#  '8 سنوات',
#  'تسكن الأسود السفانا والأراضي العشبيّة عادة،',
#  'آسيا',
#  'آسيا',
#  '8.7% من مساحة سطح الأرض الكلية',
#  '4,462 مليار نسمة،',
#  '60% من سكان العالم الحاليين.',
#  'أربع مرات تقريبًا',
#  '4/5 من أراضي أوراسيا',
#  'يحدها من الشرق المحيط الهادي،',
#  'المحيط الهندي',
#  'هو أحد ملوك مقدونيا الإغريق، ومن أشهر القادة العسكريين والفاتحين عبر التاريخ.',
#  'الإسكندر الأكبر، والإسكندر الكبير، والإسكندر المقدوني، والإسكندر ذو القرنين',
#  'Ἀλέξανδρος ὁ Μέγας؛',
#  'في مدينة پيلا',
#  'قرابة سنة 356 ق.م،',
#  'على يد الفيلسوف والعالم الشهير أرسطو',
#  'سنة 336 ق.م،',
#  'إسوس وگوگميلا.',
#  'دارا الثالث،',
#  '名探偵コナン،',
#  'سلسلة مانغا للكاتب غوشو أوياما',
#  '8 يناير 1996 في اليابان.',
#  'في 18 يونيو عام 1994',
#  '120 مليون نسخة.',
#  'بواسطة استديو طوكيو موفي شينشا،',
#  'في 8 يناير 1996',
#  '25 دقيقة،',
#  '21 فيلمًا،',
#  'CAF Champions League)،',
#  'بطولة أفريقيا للأندية الأبطال',
#  'عام 1997،',
#  'الكأس الإفريقية للأندية البطلة.',
#  'الإتحاد الإفريقى لكرة القدم.',
#  'وتتخطى شعبيتها حدود القارة السمراء إلى أوروبا والأمريكتين وجميع أنحاء العالم.',
#  'عام 1964',
#  'الأندية أبطال الدوري في البلدان الإفريقية.',
#  'تؤهل بطلها إلي بطولة كأس العالم للأندية.',
#  'تناذر داون أو التثالث الصبغي 21 أو التثالث الصبغي G',
#  'متلازمة صبغوية تنتج عن تغير في الكروموسومات؛ حيث توجد نسخة إضافية من كروموسوم 21',
#  'يسبب تغيراً في المورّثات.',
#  'بوجود تغييرات كبيرة أو صغيرة في بنية الجسم.',
#  'ضعف في القدرات الذهنية والنمو البدني، وبمظاهر وجهية مميزة.',
#  'عن طريق بزل السلى.',
#  'الطبيب البريطاني جون لانغدون داون',
#  '"المنغولية" أو "البلاهة المنغولية"',
#  'عام 1862',
#  'في شمال المحيط الأطلسي على الحافة وسط الأطلسي.',
#  '320,000 نسمة',
#  '103,000 كم2.',
#  'ريكيافيك',
#  'ريكيافيك وهي أكبر مدن البلاد، حيث أنها والمناطق الجنوبية الغربية',
#  'يقوم تيار الخليج بتلطيف مناخ آيسلندا مما يجعله معتدلاً ومناسباً للحياة',
#  'الزعيم النرويجي انجولفر ارنارسون',
#  'في 874م.',
#  'في عام 1994',
#  'Paracetamol)',
#  'Acetaminophen)،',
#  'هو مسكن وخافض للحرارة واسع الاستخدام.',
#  'بأنها مركبات موجودة في اللحاء الأبيض للصفصاف (عائلة من الكيماويات اسمها',
#  'في إنتاج الكينين لعلاج الملاريا.',
#  'الفرنسي شارل فريدريك جيرهارد',
#  'وفي سنة 1886',
#  'هينزبيرغ',
#  'هارمون نورتروب مورسه',
#  'عضو جنسي في إناث الثدييات والنعام وعدد محدود من الحيوانات الأخرى.',
#  'Clitoris)',
#  'بالقرب من التقاطع الأمامي للشفرين الصغيرين (الشفرين الداخليين)، فوق فوّهة الإحليل.',
#  'هو المنطقة المثيرة للشهوة الجنسية الأكثر حساسية عند المرأة',
#  'هو تقريبًا كحجم وشكل حبة البازلاء،',
#  'أكثر من 8000',
#  'اللغة الإغريقية القديمة',
#  'في الولايات المتحدة',
#  'بدءاً من عام 1958،',
#  'صحابي من صحابة رسول الإسلام محمد، وعمُّه وأخوه من الرضاعة وأحد وزرائه الأربعة عشر،',
#  'وَخَيْرُ أَعْمَامِي',
#  '«خَيْرُ إِخْوَتِي عَلِيٌّ،',
#  'في السنة الثانية من بعثة النبي محمد،',
#  'وقَتَلَ فيها شيبة بن ربيعة مبارزةً، وقتل غيرَه كثيراً من المشركين،',
#  'وحشي بن حرب الحبشي',
#  'سيد قريش وبني هاشم،',
#  'محمد بن عبد الله بن عبد المطلب،',
#  'صداقة متينة ووثيقة العُرا.',
#  'القمر الطبيعي الوَحيد للأرض',
#  'ربع قطر الأرض،',
#  '1 على 81 من كتلة الأرض،',
#  'تأثير جاذبيته التي تسفر عن وقوع عمليتي مد وجزر المحيطات وإطالة الدقيقة (نتيجة تسارع',
#  'تُقَدَرُ بثلاثين مرةٍ قدر قطر الكرة الأرضية،',
#  'المسافة المدارية الحالية للقمر،',
#  'للإتحاد السوفيتي',
#  'في عام 1968،',
#  '4.5 مليارات سنة',
#  'تقع غرب المملكة العربية السعودية،',
#  'حوالي 400 كيلومتر في الاتجاه الجنوبي الغربي،',
#  'حوالي 120 كيلومترا في الاتجاه الشرقي،',
#  'وعلى بعد 72 كيلومترا',
#  'حوالي 277 مترًا.',
#  'عند تقاطع درجتي العرض 25/21 شمالا، والطول 49/39 شرقا،',
#  '1675000 نسمة',
#  'الإسلامية المقدسة، لعل من أبرزها المسجد الحرام وهو أقدس الأماكن في الأرض بالنسبة للمسلمين،',
#  'المسجد الحرام وهو أقدس الأماكن في الأرض بالنسبة للمسلمين، ذلك لأنه يضم الكعبة المشرفة',
#  'هي تقسيمات دائرة البروج أو مسار الشمس',
#  'باثنی عشر قسم سماوي،',
#  'بالعين المجردة، و الأبراج هي تقسیمات للدّائرة التي تمر فيها الشمس والقمر والكواكب الثمانية.',
#  'تقسيمات دائرة البروج أو مسار الشمس',
#  'وعدد الأبراج علی دائرة البروج 12 برجاً،',
#  'تحمل الأبراج أسماء حيوانات وأشياء وشخصيات دينية وأسطورية.',
#  'نقطتين',
#  'الحمل',
#  'الميزان',
#  'شاكيرا إيزابيل مبارك ريبول',
#  'ولدت في (2 فبراير 1977)',
#  'بمدينة بارانكيا في كولومبيا،',
#  'في بارانكيا',
#  'وفي عمر الثالثة عشرة',
#  'عمر',
#  'Emilio Estefan',
#  'حوالي ثلاثة ملايين دولار.',
#  'أعطاها شعبية كبيرة في إسبانيا وفي الدول التي تتحدث الإسبانية.',
#  'يُعرف باسم الذاتوية أو اضطراب التوحد الكلاسيكي.',
#  'العصبي الذي يتصف بضعف التفاعل الاجتماعي، والتواصل اللفظي وغير اللفظي، وبأنماط سلوكية مقيدة ومتكررة.',
#  'عند الإشارة إلى مجموعة من اضطرابات طيف التوحد أو مختلف اضطرابات النمو المتفشية،',
#  'العصبي الذي يتصف بضعف التفاعل الاجتماعي، والتواصل اللفظي وغير اللفظي، وبأنماط سلوكية مقيدة ومتكررة.',
#  'في حالة عدم تواجد معايير تحديد مرض التوحد أو متلازمة أسبرجر.',
#  'عملية معالجة البيانات في المخ',
#  '1-2 من كل 1000 شخص',
#  '4 مرات أكثر من البنات.',
#  '1.5%',
#  'Manchester United Football Club)',
#  'Manchester United F.C)',
#  'نادي كرة قدم إنجليزي',
#  'أولد ترافورد',
#  '"مسرح الأحلام"',
#  'بمدينة مانشستر إنجلترا',
#  '1 مارس 1878م',
#  'نويتن هيث',
#  '1908م',
#  'هي ديانة إبراهيمية، وتوحيدية، متمحورة في تعاليمها حول الكتاب المقدس، وبشكل خاص يسوع،',
#  'النَّصْرَانيّة،',
#  'هي ديانة إبراهيمية،',
#  'تعدّ أكبر دين معتنق في البشرية،',
#  '2.4 مليار',
#  'فالمسيحية دين الأغلبية السكانية في 126 بلدًا من أصل 197',
#  'Χριστιανισμός)',
#  'الممسوح بالدهن المقدس،',
#  'الممسوح بالدهن المقدس،',
#  'حُجر',
#  '(500',
#  '540 م)',
#  'هو شاعرعربي',
#  'بَرز في فترةِ الجاهلية،',
#  'فورد باسم جندح وحندج ومليكة وعدي،',
#  'ولد في نجد لقبيلة كندة اليمنية،',
#  'كان أبوه حجر ملكاً على بني أسد وغطفان،',
#  'فاطمة بنت ربيعة أخت كليب',
#  'Kavalalı Mehmet Ali Paşa؛',
#  'Mehmet Ali Pasha)،',
#  'بالعزيز أو عزيز مصر،',
#  '17 يناير 1942',
#  '3 يونيو 2016',
#  '"رياضي القرن"،',
#  '1,000 باوند.',
#  'عام 1981',
#  '39 عامًا،',
#  'England',
#  'هي أكبر دولة في المملكة المتحدة',
#  'الشمال وويلز في الغرب والبحر الأيرلندي في الشمال الغربي وبحر الكلت في الجنوب الغربي',
#  'القناة الإنجليزية',
#  '100 جزيرة صغيرة،',
#  'جزر سيلي وجزيرة وايت.',
#  'في فترة العصر الحجري القديم،',
#  'ويعود أصل كلمة إنجلترا إلى الآنجلز وهي إحدى قبائل الجرمان',
#  'استقرت خلال القرن الخامس والسادس الميلادي.',
#  '(1165',
#  '1227م)',
#  'الإمبراطورية المغولية',
#  'بحق المسلمين.',
#  'فهاجم خانات قراخيطان والقوقاز والدولة الخوارزمية وزيا الغربية وإمبراطورية جين.',
#  'رحل لشمال شرق آسيا.',
#  'أوقطاي خان',
#  'إلى خانات بين أبنائه وأحفاده.',
#  'الصين الحالية وكوريا والقوقاز وممالك آسيا الوسطى، وأجزاء ضخمة من أوروبا الشرقية والشرق الأوسط.',
#  'سليم خان الأول',
#  'Sultan Süleyman-ı Evvel)',
#  '6 نوفمبر 1494',
#  'الملوك الأول وسفر أخبار الأيام الأول وحسب التلمود، هو أحد الأنبياء الثمانية والأربعين وابن',
#  'وهي المملكة التي بقي يحكمها قبائل إسرائيل الإثنا عشر ومملكة يهوذا في الجنوب',
#  'وثرائه وملكه الكبير وعدد من الذنوب التي بموجبها عاقب يهوه بني إسرائيل بتقسيم مملكتهم',
#  'ابيشج الشونمية"',
#  'أدونيا وأبشالوم وأمنون وشفطيا ويثرعام وكيلاب',
#  'أدونيا',
#  '27 محافظة',
#  '7 أقاليم،',
#  'المراكز الإدارية توجد في المحافظات التي بها ريف،',
#  'الوحدة المحلية تكون قرية رئيسية أو مدينة (إذا كان المركز يتبعه أكثر من مدينة)؛',
#  'يُسمى برئيس الحي،',
#  'ويعين رئيس المدينة رؤساء تلك الأحياء الصغيرة أو الشياخات.',
#  'قسم نابليون بونابرت البلاد إلى 16 مديرية،',
#  'منذ عام 1805؛ قسّم البلاد إلى 14 مديرية بجانب محافظات حضرية وقسمت كل مديرية',
#  'التقسيم الإداري المصري بشكل نظامي لأول مرة بعد توحد القطر المصري في نظام مركزي',
#  'تأسست منظمة الأمم المتحدة بتاريخ 24 أكتوبر 1945',
#  'لمؤتمر دومبارتون أوكس الذي عقد في العاصمة واشنطن.',
#  'في مدينة سان فرانسيسكو، كاليفورنيا الأمريكية،',
#  'يتم تمويل المنظمة من خلال المساهمات المقدرة والمساهمات الطوعية من الدول الأعضاء فيها.',
#  'توجد مكاتب رئيسية أخرى في جنيف ونيروبي وفيينا.',
#  'والأمن الدوليين ، وحماية حقوق الإنسان ، وتقديم المساعدات الإنسانية ، وتعزيز التنمية المستدامة',
#  'كان يوجد منظمة شبيهة بمنظمة الأمم المتحدة تدعى عصبة الأمم',
#  '1919',
#  'الحرب العالمية الثانية، مما أدى إلى نشوء الأمم المتحدة بعد إنتصار الحلفاء وتم إلغاء',
#  'في أوروبا الوسطى.',
#  'النمسا هي جمهورية فيدرالية',
#  'التشيك وألمانيا في الشمال والمجر وسلوفاكيا إلى الشرق وسلوفينيا وإيطاليا من الجنوب، وسويسرا وليختنشتاين',
#  'حاليا،النظام السياسي في النمسا هو الديمقراطية التمثيلية البرلمانية شبه رئاسي',
#  'يتجاوز عدد سكانها 1.7 مليون نسمة',
#  'في عام 1995،',
#  'وهو من اللغة السلافية القديمة "němьcь"',
#  'تعني الأجنبي أو الألماني',
#  'وكل هذه التسميات للألمان والنسماويون أصلها واحد.',
#  'الجمهورية الإسلامية الموريتانية)،',
#  'تقع في شمال غرب أفريقيا وعلى شاطئ المحيط الأطلسي،',
#  'يحدها من الشمال كل من المغرب والجزائر، ومن الجنوب السنغال، ومن الشرق والجنوب مالي،',
#  'خلال القرن الخامس والسادس الهجري في منطقة المغرب الإسلامي',
#  'انبثقت دولة المرابطين من حركة دعوية إصلاحية إسلامية اعتمدت في بدايتها على العصبية الصنهاجية',
#  '«دولة الرباط والإصلاح».',
#  'في القرن السادس الهجري',
#  'من صعيد مصر ضمن الهجرة الهلالية الشهيرة إلى بلدان المغرب العربي',
#  'واجهت معارضة شديدة من القبائل الأمازيغية',
#  '(15 يناير 1937',
#  'كلية الزراعة جامعة الإسكندرية،',
#  'أشهرها (طبيخ الملايكة) و(روميو وجوليت)،',
#  'وكان آخر عمل مسرحي لهما معًا هو مسرحية (اهلا يا دكتور).',
#  'فرقة ثلاثي أضواء المسرح',
#  'انحلت الفرقة بعد وفاة الضيف أحمد عام 1970،',
#  'ولد سمير غانم في عرب الأطاولة من محافظة أسيوط،',
#  'انضم بعد الثانوية العامة إلى كلية الشرطة احتذاءً بوالده الذي كان ضابط شرطة',
#  'لسنتين متتاليتين فنقل أوراق إلى كلية الزراعة في جامعة الإسكندرية كما انضم للفرق الفنية',
#  'كفر المصيلحة،',
#  'في 11 فبراير 2011',
#  'للمجلس الأعلى للقوات المسلحة.',
#  'الكلية الجوية',
#  '14 أكتوبر 1981',
#  '2005،',
#  'حكمه كان قمعيا،',
#  '1989',
#  'عرف بموقفه الداعم للمفاوضات السلمية الفلسطينية - الإسرائيلية،',
#  'Монголын Эзэнт Гүрэн،',
#  'وثاني أضخم إمبراطورية في التاريخ من حيث المساحة بعد الإمبراطورية البريطانية،',
#  'وأعظم رعب مر على تاريخ أوراسيا.',
#  'وهي نتاج توحيد قبائل المغول والترك في مايسمى حاليا منغوليا،',
#  '(جنكيز خان)',
#  '100 مليون نسمة',
#  'في أعقاب الحرب على وراثة الحكم ما بين عاميّ 1260 و1264',
#  'انقسمت الإمبراطورية إلى أربعة خانات أو إمبراطوريات، كل منها يهدف لتحقيق مصالحه واهتماماته الخاصة،',
#  'حتى القرن السابع عشر.',
#  'عام 15 هـ (636)',
#  'المسلمين والروم',
#  'لأنها كانت بداية أول موجة انتصارات للمسلمين خارج جزيرة العرب،',
#  'وآذنت لتقدم الإسلام السريع في بلاد الشام.',
#  'حدثت بعد وفاة الرسول عام 632 بأربع سنوات.',
#  '(الإمبراطورية البيزنطية)،',
#  'خالد بن الوليد',
#  '36 ألف مقاتل',
#  '240 ألف مقاتل.',
#  'بوسط المحيط الهندي',
#  'الرحالة البرتغالي دون بيدرو ماسكارينهاس',
#  'في العام 1505',
#  '1638.',
#  '1810',
#  '12 مارس 1968،',
#  '62 عضواً',
#  'كل 5 أعوام.',
#  'فرئيس الوزراء',
#  'نسبة إلى علي بن أبي طالب',
#  'طائفة من الشيعة الجعفرية الإثني عشرية، تتميّز عن بقية الإثني عشرية بإيمانهم بالأدلة العقلية.',
#  'بـالنُصيرية؛',
#  '7-14 مليون',
#  'يسكن أغلبهم سوريا وفي الأقاليم السورية الشمالية ولواء الإسكندرون',
#  'تتميّز عن بقية الإثني عشرية بإيمانهم بالأدلة العقلية.',
#  'الإمام حسن العسكري',
#  'عبر وسطاء محددين، وهم ماسماهم الناس "السفراء"،',
#  'أربعة أشخاص.',
#  'هو مسكن ألم مركزي',
#  'ويصنف ضمن مسكنات الألم من النوع 2.',
#  'يؤثر على نفس مستقبلات المورفين،',
#  'له مفعول مقارب للكودايين،',
#  'وهو يسبب ادمانا ولكن بصفة أقل من باقي المورفينات',
#  'له خطورة بالغة جدا ويسبب الكثير من الأمراض العصبية',
#  'تأثيره المسكن للألم أكبر من المسكنات من النوع 1،',
#  'ويمكن اٍستخدامه عن طريق الحقن الوريدي،',
#  'من 50 إلى 250ملغ.',
#  'استمرت من 1789 حتى 1799،',
#  'لها تأثيرات عميقة على أوروبا والعالم الغربي عموما،',
#  'انتهت بسيطرة البورجوازية',
#  'بسيطرة البورجوازية خلال التحالف مع نابليون',
#  'إحقاق مجموعة من الحقوق والحريات للطبقة العاملة والمتوسطة للشعب الفرنسي.',
#  'بشكل عميق مسار التاريخ الحديث، وأطلقت الانحدار العالمي للملكيات المطلق واستبدالها بالجمهوريات.',
#  'وحاولت استعادة وضعها المالي من خلال خطط ضرائب لم تحظى بشعبية بين العامة.',
#  'في مايو 1789',
#  'ألغي نظام الإقطاع والقواعد والامتيازات القديمة التي خلفها حكم أترافي.',
#  'مع المغنية أصالة في كليب "لما جت عينك في عيني"ز',
#  'إيناس الدغيدي التي أتاحت له الفرصة',
#  'فيلم فيلم كلام الليل',
#  'فيلم مذكرات مراهقة.',
#  'لعب دور البطولة أمام الفنانة يسرا',
#  'واتّجه لأفلام الحركة والإثارة والتشويق.',
#  'الإنتاج السينمائي وقتها كان محدوداً جداً وخشي من عدم وجود فرصة بعد ذلك للعمل،',
#  'فدرس الأدب الإنجليزي في كلية الآداب جامعة عين شمس،',
#  'وبعد تخرّجه عمل في مجال الفنادق.',
#  'رونالدو لويس نازاريو دي ليما',
#  'ويُعرف أيضاً بلقبه "الظاهرة"',
#  'في فبراير عام 2011،',
#  'وُلد يوم 22 سبتمبر عام 1976',
#  'ويتميّزُ بالسرعة والمهارة العالية وبالبراعة في الإنهاء أمام المرمى،',
#  'فاز بجائزة الفيفا لأفضل لاعب في العالم وهو بسنّ العشرين عاماً عام 1996،',
#  'نادي كروزيرو في البرازيل عام 1993',
#  'لقُطبي إسبانيا برشلونة بين عامي 1996–1997 وريال مدريد بين عامي 2002–2007',
#  'نادي كورينثيانز الذي قضى معه آخر سنتين في مسيرته الكروية.',
#  'القرآني أخبر بحقائق كونية لم تكن مدركة للبشر في زمن ثبوت النص القرآني وأثبتها',
#  'القرآني أخبر بحقائق كونية لم تكن مدركة للبشر في زمن ثبوت النص القرآني وأثبتها',
#  'القرآني أخبر بحقائق كونية لم تكن مدركة للبشر في زمن ثبوت النص القرآني وأثبتها',
#  'يؤمن المسلمون أن القرآن معجزة النبي محمد للعالمين،',
#  'معلومات علميّة كثيرة في عدد من الآيات وهو ما يسمى بالإعجاز العلمي في القرآن،',
#  'الإعجاز العلمي يعني توافق النص القرآني مع مقتضيات العلم الحديث أو وجود إلماحات أو',
#  'عدّة محاضرات جامعية وتلفازية بين ما جاء في بعض الآيات وما أقرّته نظريات علمية',
#  'انفجار عظيم، وأن أدنى نقطة على سطح الأرض هي البحر الميت، وأن الجنين يُخلق',
#  'الروم البيزنطيين خلال عقد العشرينيات من القرن السابع، بعد أن كان الفرس قد هزموا',
#  '(15 يناير 1918',
#  'سنة 1956',
#  '1918',
#  'سنة 1962،',
#  'سنة 1964،',
#  'مارس 1965',
#  'سنة 1970،',
#  'أكثر من خمسة ملايين شخص.',
#  'باعتباره واحداً من الشخصيات السياسية البارزة في التاريخ الحديث للشرق الأوسط في القرن العشرين.',
#  'في الشرق الأوسط من جنوب غرب القارة الآسيوية،',
#  '17،818 كيلومتر مربع،',
#  '4,675,710 ملايين نسمة.',
#  'ملكي دستوري،',
#  'مدينة الكويت',
#  'عام 1963.',
#  'عام 1936',
#  '30 يونيو سنة 1946.',
#  'قرابة 45,455 دولار أمريكي',
#  '23 يونيو 1972',
#  'لاعب كرة قدم فرنسي من أصل جزائري،',
#  '3 مرات،',
#  '4 يناير عام 2016،',
#  '9 بطولات في عامين ونصف',
#  'دوري أبطال أوروبا ثلاث مرات متتالية',
#  'إسماعيل ومليكة',
#  '1953م',
#  'وفي منتصف 1960م',
#  'في أمريكا الشمالية',
#  'من 10 مقاطعات وثلاثة أقاليم.',
#  'عام 1982',
#  'ديمقراطي تمثيلي وملكية دستورية',
#  'الإنكليزية والفرنسية',
#  'علاقة طويلة ومعقدة.',
#  '"كنتا"، وهي كلمة ترجع إلى لغة الإيروكواس في سانت لورانس وتعني قرية أو مستوطنة.',
#  'في عام 1535،',
#  'المستكشف الفرنسي جاك كارتييه',
#  '(19 نوفمبر 1954)،',
#  'سنة 2014',
#  '12 أغسطس 2012',
#  'أفرادا من الشرطة العسكرية قد أجروا، في مارس 2011، ما عُرف إعلاميًا بكشوف العذرية،',
#  'أنها مبررة؛',
#  'لأنها تحمي الفتيات من الاغتصاب وتحمي الجنود من الاتهام بالاغتصاب.',
#  'رئيس المخابرات الحربية والاستطلاع.',
#  'في 12 أغسطس 2012،',
#  'الرئيس آنذاك محمد مرسي',
#  'في عهد الرسول محمد،',
#  '662 - 750 م)',
#  'معاوية بن أبي سفيان',
#  'المغرب، وفتحت الأندلس بكاملها، وفتحت السند بقيادة محمد بن القاسم الثقفي وبلاد ما وراء',
#  'عمر بن عبد العزيز،',
#  'محمد على الخلافة، فأخذ يتنقل بين الأقاليم ويقمع الثورات والاضطرابات، ثم التقى مع العباسيين',
#  'ثورات وفتناً كثيرة،',
#  'ثورة الحسين بن علي على يزيد بن معاوية،',
#  'الحجاج بن يوسف الثقفي',
#  'هي أهم مسابقة لرياضة كرة القدم تقام تحت إشراف الاتحاد الدولي لكرة القدم.',
#  ...]

# %% [markdown]
# **load training data, parse, and split**

# %%
print('Loading in training data')
trainData =import_qas_data('arcd.json')
tContext, tQuestion, tQuestion_id, tAnswerBegin, tAnswerEnd, tAnswerText, maxLenTContext, maxLenTQuestion = splitDatasets(trainData)
# Out:
# Loading in training data

# %%
print('Loading in Validation data...')
valData = import_qas_data('arcd-test.json')
vContext, vToken2CharIdx, vContextOriginal, vQuestion, vQuestion_id, maxLenVContext, maxLenVQuestion = splitValDatasets(valData)
# Out:
# Loading in Validation data...

# %% [markdown]
# # **Building vocabulary**

# %%
print('Building vocabulary...')
# build a vocabular over all training and validation context paragraphs and question words
vocab = {}
for words in tContext + tQuestion + vContext + vQuestion:
    for word in words:
        if word not in vocab:
            vocab[word] = 1
vocab = sorted(vocab.keys())  

# Reserve 0 for masking via pad_sequences
vocab_size = len(vocab) + 1
word_index = dict((c, i + 1) for i, c in enumerate(vocab))
print(word_index)
context_maxlen = max(maxLenTContext, maxLenVContext)
question_maxlen = max(maxLenTQuestion, maxLenVQuestion)
# Out:
# Building vocabulary...
# {'!': 1, '"': 2, '$': 3, '%': 4, "'": 5, "'che": 6, "'s": 7, '(': 8, ')': 9, '*': 10, ',': 11, '-': 12, '-10': 13, '-عاصمة': 14, '-في': 15, '-كلاي-،': 16, '-وفق': 17, '-ومعهم': 18, '.': 19, '..': 20, '...': 21, '.ترك': 22, '.كتب': 23, '.وذات': 24, '.يقول': 25, '/': 26, '/ʃəˈkiːrə/': 27, '/ˌɛkˈsəʊ/': 28, '0°': 29, '1': 30, '1,000': 31, '1-2': 32, '1.002.000': 33, '1.1': 34, '1.2': 35, '1.338': 36, '1.5': 37, '1.5٪': 38, '1.7': 39, '1.8': 40, '10': 41, '10,000': 42, '10.180': 43, '100': 44, '100,000': 45, '1000': 46, '10000000': 47, '103,000': 48, '1037م': 49, '1040م': 50, '1071م': 51, '1093': 52, '11': 53, '11,900,000': 54, '11-14': 55, '11.2': 56, '1115': 57, '1138': 58, '114': 59, '1157': 60, '1157م': 61, '1165': 62, '117': 63, '1171م': 64, '1193': 65, '11،787': 66, '12': 67, '120': 68, '1204': 69, '1206': 70, '1227': 71, '1227م': 72, '1233': 73, '125': 74, '1258م،': 75, '126': 76, '1260': 77, '1262': 78, '127': 79, '128': 80, '1280': 81, '1281م،': 82, '1295م': 83, '1299م': 84, '12ربیع': 85, '13': 86, '1304،': 87, '1308': 88, '1319': 89, '1319هـ': 90, '132': 91, '1326م': 92, '1332': 93, '1342': 94, '1350،': 95, '1351': 96, '1354م،': 97, '1366م': 98, '1388': 99, '1393': 100, '14': 101, '14,500': 102, '14.3': 103, '140': 104, '1405': 105, '1406': 106, '1406م': 107, '1419': 108, '1420': 109, '1426': 110, '1453م،': 111, '1492': 112, '1492م': 113, '1494': 114, '15': 115, '150': 116, '150-204هـ': 117, '15000': 118, '1505': 119, '1517م،': 120, '1520م': 121, '1529م': 122, '1535،': 123, '1545،': 124, '1565م؛': 125, '1566': 126, '1566م': 127, '158': 128, '1585م': 129, '1598،': 130, '15؟': 131, '16': 132, '1638': 133, '167.9': 134, '1675000': 135, '17': 136, '1710': 137, '1715': 138, '1744': 139, '1763': 140, '1789': 141, '179': 142, '1792': 143, '1793': 144, '1798': 145, '1799،': 146, '17،818': 147, '18': 148, '18-22': 149, '1800': 150, '1801': 151, '1805': 152, '1805؛': 153, '1810': 154, '1818م،': 155, '1821': 156, '184': 157, '1847-1931': 158, '1848،': 159, '185180': 160, '1854': 161, '1858': 162, '1862': 163, '1863': 164, '1866': 165, '1867،': 166, '1870': 167, '1871-1919': 168, '1872': 169, '1878،': 170, '1878م': 171, '1879': 172, '1880،': 173, '1881،': 174, '1883': 175, '1884': 176, '1886': 177, '1891': 178, '1891،': 179, '1892،': 180, '1892م': 181, '1893': 182, '1894': 183, '1895': 184, '1895،': 185, '1896-1915': 186, '1898م،': 187, '1899': 188, '1899،': 189, '19': 190, '1900': 191, '1900،': 192, '1901-2000': 193, '1901،': 194, '1902': 195, '1902،': 196, '1902م': 197, '1905': 198, '1905،': 199, '1907': 200, '1907،': 201, '1908': 202, '1908م': 203, '1909': 204, '1909م': 205, '1911': 206, '1911،': 207, '1912': 208, '1912-1913': 209, '1912،': 210, '1912؟': 211, '1914': 212, '1914،': 213, '1915': 214, '1916': 215, '1916م': 216, '1917': 217, '1917–1923': 218, '1918': 219, '1918،والذي': 220, '1919': 221, '1919؟': 222, '1920': 223, '1921': 224, '1921،': 225, '1922': 226, '1922-1991؟': 227, '1922م': 228, '1923': 229, '1923م': 230, '1926،': 231, '1928': 232, '1928،': 233, '1930': 234, '1930،': 235, '1930م': 236, '1931': 237, '1932': 238, '1934': 239, '1934،': 240, '1936': 241, '1937': 242, '1937،': 243, '1938': 244, '1938،': 245, '1939': 246, '1939،': 247, '1941': 248, '1941،': 249, '1942': 250, '1945': 251, '1945،': 252, '1946': 253, '1946،': 254, '1947': 255, '1948': 256, '1948،': 257, '1949': 258, '1949،': 259, '195': 260, '1950،': 261, '1951': 262, '1952': 263, '1953': 264, '1953،': 265, '1953الى': 266, '1953م': 267, '1954': 268, '1954،': 269, '1955': 270, '1956': 271, '1956،': 272, '1956م': 273, '1957': 274, '1957،': 275, '1958': 276, '1958،': 277, '1958م': 278, '1959': 279, '1959،': 280, '1960': 281, '1960م': 282, '1961': 283, '1961،': 284, '1962': 285, '1962،': 286, '1963': 287, '1963،': 288, '1963م': 289, '1964': 290, '1964،': 291, '1964؟': 292, '1964م': 293, '1965': 294, '1965م': 295, '1966': 296, '1967': 297, '1967،': 298, '1968،': 299, '1968م': 300, '1969': 301, '1969م': 302, '197': 303, '1970': 304, '1970،': 305, '1971': 306,  ...

# %%
vocab_size
# Out:
# 16353

# %%
context_maxlen
# Out:
# 349

# %%
question_maxlen
# Out:
# 17

# %% [markdown]
# # **vectorizeData**

# %%
def vectorizeData(xContext, xQuestion, xAnswerBeing, xAnswerEnd, word_index, context_maxlen, question_maxlen):
    
    X = []
    Xq = []
    YBegin = []
    YEnd = []
    for i in range(len(xContext)):
        x = [word_index[w] for w in xContext[i]]
        xq = [word_index[w] for w in xQuestion[i]]
        # map the first and last words of answer span to one-hot representations
        y_Begin =  np.zeros(len(xContext[i]))
        y_Begin[xAnswerBeing[i]] = 1
        y_End = np.zeros(len(xContext[i]))
        y_End[xAnswerEnd[i]] = 1
        X.append(x)
        Xq.append(xq)
        YBegin.append(y_Begin)
        YEnd.append(y_End)
    return pad_sequences(X, maxlen=context_maxlen, padding='post'), pad_sequences(Xq, maxlen=question_maxlen, padding='post'), pad_sequences(YBegin, maxlen=context_maxlen, padding='post'), pad_sequences(YEnd, maxlen=context_maxlen, padding='post')

# %%
# for validation dataset
def vectorizeValData(xContext, xQuestion, word_index, context_maxlen, question_maxlen):
    
    X = []
    Xq = []
    YBegin = []
    YEnd = []
    for i in range(len(xContext)):
        x = [word_index[w] for w in xContext[i]]
        xq = [word_index[w] for w in xQuestion[i]]

        X.append(x)
        Xq.append(xq)

    return pad_sequences(X, maxlen=context_maxlen, padding='post'), pad_sequences(Xq, maxlen=question_maxlen, padding='post')

# %% [markdown]
# # **vectorize training and validation datasets**

# %%
print('Begin vectoring process...')
#tX: training Context, tXq: training Question, tYBegin: training Answer Begin ptr, tYEnd: training Answer End ptr
tX, tXq, tYBegin, tYEnd = vectorizeData(tContext, tQuestion, tAnswerBegin, tAnswerEnd, word_index, context_maxlen, question_maxlen)
# Out:
# Begin vectoring process...

# %%
#vX: validation Context, vXq: validation Question
vX, vXq = vectorizeValData(vContext, vQuestion, word_index, context_maxlen, question_maxlen)
print('Vectoring process completed.')
# Out:
# Vectoring process completed.

# %%
# shuffle train data
randindex = np.random.permutation(tX.shape[0])
tX = tX[randindex, :]
tXq = tXq[randindex, :]
tYBegin = tYBegin[randindex, :]
tYEnd = tYEnd[randindex, :]

# %% [markdown]
# **shape**

# %%
print('tX.shape = {}'.format(tX.shape))
print('tXq.shape = {}'.format(tXq.shape))
print('tYBegin.shape = {}'.format(tYBegin.shape))
print('tYEnd.shape = {}'.format(tYEnd.shape))
print('vX.shape = {}'.format(vX.shape))
print('vXq.shape = {}'.format(vXq.shape))
print('context_maxlen, question_maxlen = {}, {}'.format(context_maxlen, question_maxlen))
# Out:
# tX.shape = (1395, 349)
# tXq.shape = (1395, 17)
# tYBegin.shape = (1395, 349)
# tYEnd.shape = (1395, 349)
# vX.shape = (702, 349)
# vXq.shape = (702, 17)
# context_maxlen, question_maxlen = 349, 17

# %% [markdown]
# # **Model**

# %% [markdown]
# **Import**

# %%
from keras.layers import recurrent
from keras.layers import recurrent, Input, Bidirectional, LSTM, Lambda
from keras import layers
from keras.layers import concatenate
from keras.layers import Dense,  Dropout, RepeatVector
from keras.models import Model
from keras import optimizers
from keras.optimizers import Adam, RMSprop
from keras.layers import LSTM, Bidirectional, TimeDistributed, GRU, AveragePooling1D, Reshape, GlobalAveragePooling1D
# !pip install keras-metrics
import keras
import keras_metrics as km
# Out:
# Collecting keras-metrics
#   Downloading https://files.pythonhosted.org/packages/32/c9/a87420da8e73de944e63a8e9cdcfb1f03ca31a7c4cdcdbd45d2cdf13275a/keras_metrics-1.1.0-py2.py3-none-any.whl
# Requirement already satisfied: Keras>=2.1.5 in /usr/local/lib/python3.6/dist-packages (from keras-metrics) (2.3.1)
# Requirement already satisfied: keras-preprocessing>=1.0.5 in /usr/local/lib/python3.6/dist-packages (from Keras>=2.1.5->keras-metrics) (1.1.2)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.6/dist-packages (from Keras>=2.1.5->keras-metrics) (3.13)
# Requirement already satisfied: numpy>=1.9.1 in /usr/local/lib/python3.6/dist-packages (from Keras>=2.1.5->keras-metrics) (1.18.4)
# Requirement already satisfied: keras-applications>=1.0.6 in /usr/local/lib/python3.6/dist-packages (from Keras>=2.1.5->keras-metrics) (1.0.8)
# Requirement already satisfied: h5py in /usr/local/lib/python3.6/dist-packages (from Keras>=2.1.5->keras-metrics) (2.10.0)
# Requirement already satisfied: scipy>=0.14 in /usr/local/lib/python3.6/dist-packages (from Keras>=2.1.5->keras-metrics) (1.4.1)
# Requirement already satisfied: six>=1.9.0 in /usr/local/lib/python3.6/dist-packages (from Keras>=2.1.5->keras-metrics) (1.12.0)
# Installing collected packages: keras-metrics
# Successfully installed keras-metrics-1.1.0

# %% [markdown]
# **Arab QA Model**

# %%
EMBED_HIDDEN_SIZE = 50
SENT_HIDDEN_SIZE = 100
QUERY_HIDDEN_SIZE = 100
BATCH_SIZE = 32
print(' Embed / Sent / Query =  {}, {}, {}'.format( EMBED_HIDDEN_SIZE,SENT_HIDDEN_SIZE,QUERY_HIDDEN_SIZE))
# Out:
#  Embed / Sent / Query =  50, 100, 100

# %% [markdown]
# **input , Embedding layer**

# %%
cinput = Input(shape=(context_maxlen,), dtype='int32', name='cinput')
cembed= layers.Embedding(vocab_size, EMBED_HIDDEN_SIZE)(cinput)

qinput = Input(shape=(question_maxlen,), dtype='int32', name='qinput')
qembed = layers.Embedding(vocab_size, EMBED_HIDDEN_SIZE)(qinput)

# %% [markdown]
# **bidirectional GRU layers**

# %%
Q = Bidirectional(GRU(64, return_sequences=True))(qembed)
D = Bidirectional(GRU(64, return_sequences=True))(cembed)
Q1 = Bidirectional(GRU(96, return_sequences=True))(Q)
D1 = Bidirectional(GRU(96, return_sequences=True))(D)
Q2 = Bidirectional(GRU(128, return_sequences=False))(Q1)
D2 = Bidirectional(GRU(128, return_sequences=False))(D1)

# %%
L = concatenate([D2, Q2])
answerPtrBegin_output = Dense(context_maxlen, activation='softmax')(L)
Lmerge = concatenate([L, answerPtrBegin_output])
answerPtrEnd_output = Dense(context_maxlen, activation='softmax')(Lmerge)

# %%
model = Model(input=[cinput, qinput], output=[answerPtrBegin_output, answerPtrEnd_output])
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:1: UserWarning: Update your `Model` call to the Keras 2 API: `Model(inputs=[<tf.Tenso..., outputs=[<tf.Tenso...)`
#   """Entry point for launching an IPython kernel.

# %%
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy',km.f1_score()])
# Out:
# tracking <tf.Variable 'Variable:0' shape=() dtype=int32, numpy=0> tp
# tracking <tf.Variable 'Variable:0' shape=() dtype=int32, numpy=0> fp
# tracking <tf.Variable 'Variable:0' shape=() dtype=int32, numpy=0> tp
# tracking <tf.Variable 'Variable:0' shape=() dtype=int32, numpy=0> fn

# %%
model.summary()
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# cinput (InputLayer)             (None, 349)          0
# __________________________________________________________________________________________________
# qinput (InputLayer)             (None, 17)           0
# __________________________________________________________________________________________________
# embedding_1 (Embedding)         (None, 349, 50)      817650      cinput[0][0]
# __________________________________________________________________________________________________
# embedding_2 (Embedding)         (None, 17, 50)       817650      qinput[0][0]
# __________________________________________________________________________________________________
# bidirectional_2 (Bidirectional) (None, 349, 128)     44160       embedding_1[0][0]
# __________________________________________________________________________________________________
# bidirectional_1 (Bidirectional) (None, 17, 128)      44160       embedding_2[0][0]
# __________________________________________________________________________________________________
# bidirectional_4 (Bidirectional) (None, 349, 192)     129600      bidirectional_2[0][0]
# __________________________________________________________________________________________________
# bidirectional_3 (Bidirectional) (None, 17, 192)      129600      bidirectional_1[0][0]
# __________________________________________________________________________________________________
# bidirectional_6 (Bidirectional) (None, 256)          246528      bidirectional_4[0][0]
# __________________________________________________________________________________________________
# bidirectional_5 (Bidirectional) (None, 256)          246528      bidirectional_3[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 512)          0           bidirectional_6[0][0]
#                                                                  bidirectional_5[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 349)          179037      concatenate_1[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 861)          0           concatenate_1[0][0]
#                                                                  dense_1[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 349)          300838      concatenate_2[0][0]
# ==================================================================================================
# Total params: 2,955,751
# Trainable params: 2,955,751
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
model.fit([tX, tXq], [tYBegin, tYEnd], epochs=80, batch_size=128, shuffle=True, validation_split=0.2)
# Out:
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/indexed_slices.py:434: UserWarning: Converting sparse IndexedSlices to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   "Converting sparse IndexedSlices to a dense Tensor of unknown shape. "
# Train on 1116 samples, validate on 279 samples
# Epoch 1/80
# 1116/1116 [==============================] - 65s 58ms/step - loss: 11.5410 - dense_1_loss: 5.7580 - dense_2_loss: 5.7669 - dense_1_accuracy: 0.0206 - dense_1_f1_score: 0.0000e+00 - dense_2_accuracy: 0.0072 - dense_2_f1_score: 0.0000e+00 - val_loss: 10.8251 - val_dense_1_loss: 5.3615 - val_dense_2_loss: 5.4380 - val_dense_1_accuracy: 0.0215 - val_dense_1_f1_score: 0.0000e+00 - val_dense_2_accuracy: 0.
80
# 1116/1116 [==============================] - 58s 52ms/step - loss: 0.1605 - dense_1_loss: 0.0772 - dense_2_loss: 0.0844 - dense_1_accuracy: 0.9946 - dense_1_f1_score: 1.0000 - dense_2_accuracy: 0.9937 - dense_2_f1_score: 0.8889 - val_loss: 22.1096 - val_dense_1_loss: 11.3302 - val_dense_2_loss: 11.2597 - val_dense_1_accuracy: 0.0179 - val_dense_1_f1_score: 0.0620 - val_dense_2_accuracy: 0.0108 - val_dense_2_f1_score: 0.0303
# Epoch 79/80
# 1116/1116 [==============================] - 58s 52ms/step - loss: 0.1514 - dense_1_loss: 0.0720 - dense_2_loss: 0.0786 - dense_1_accuracy: 0.9955 - dense_1_f1_score: 1.0000 - dense_2_accuracy: 0.9946 - dense_2_f1_score: 1.0000 - val_loss: 22.1862 - val_dense_1_loss: 11.3644 - val_dense_2_loss: 11.2858 - val_dense_1_accuracy: 0.0108 - val_dense_1_f1_score: 0.0620 - val_dense_2_accuracy: 0.0108 - val_dense_2_f1_score: 0.0303
# Epoch 80/80
# 1116/1116 [==============================] - 59s 52ms/step - loss: 0.1459 - dense_1_loss: 0.0713 - dense_2_loss: 0.0755 - dense_1_accuracy: 0.9946 - dense_1_f1_score: 0.9948 - dense_2_accuracy: 0.9946 - dense_2_f1_score: 0.8849 - val_loss: 22.1883 - val_dense_1_loss: 11.3560 - val_dense_2_loss: 11.2936 - val_dense_1_accuracy: 0.0108 - val_dense_1_f1_score: 0.0651 - val_dense_2_accuracy: 0.0108 - val_dense_2_f1_score: 0.0317

# %%
print(model.metrics_names)
# Out:
# ['loss', 'dense_1_loss', 'dense_2_loss', 'dense_1_accuracy', 'dense_1_f1_score', 'dense_2_accuracy', 'dense_2_f1_score']

# %%
acc = model.evaluate([tX, tXq], [tYBegin, tYEnd])
print(acc)
# Out:
# 1395/1395 [==============================] - 17s 12ms/step
# [4.5458252009525095, 2.386707067489624, 2.325065851211548, 0.7985662817955017, 0.9330125451087952, 0.800000011920929, 0.9127916693687439]

# %%
predictions = model.predict([vX, vXq], batch_size=128)

# %%
print(predictions[0].shape, predictions[1].shape)
# make class prediction
ansBegin = np.zeros((predictions[0].shape[0],), dtype=np.int32)
ansEnd = np.zeros((predictions[0].shape[0],),dtype=np.int32) 
for i in range(predictions[0].shape[0]):
	ansBegin[i] = predictions[0][i, :].argmax()
	ansEnd[i] = predictions[1][i, :].argmax()
print(ansBegin.min(), ansBegin.max(), ansEnd.min(), ansEnd.max())
# Out:
# (702, 349) (702, 349)
# 0 344 0 348

# %%
# extract answer tokens and join them
answers = {}
for i in range(len(vQuestion_id)):
    #print i
    if ansBegin[i] >= len(vContext[i]):
        answers[vQuestion_id[i]] = ""
    elif ansEnd[i] >= len(vContext[i]):
        answers[vQuestion_id[i]] = vContextOriginal[i][vToken2CharIdx[i][ansBegin[i]]:]
    else:
        answers[vQuestion_id[i]] = vContextOriginal[i][vToken2CharIdx[i][ansBegin[i]]:vToken2CharIdx[i][ansEnd[i]]+len(vContext[i][ansEnd[i]])]

# %%
# write out answers to json file
import io
with io.open('result', 'w', encoding='utf-8') as f:
    f.write((json.dumps(answers, ensure_ascii=False)))

# %%
pacc = model.evaluate([vX, vXq], [predictions[0], predictions[1]])
print(pacc)
# Out:
# 702/702 [==============================] - 9s 12ms/step
# [1.0261926892136577, 0.502328634262085, 0.523270845413208, 1.0, 0.9545453786849976, 1.0, 0.9090908169746399]
